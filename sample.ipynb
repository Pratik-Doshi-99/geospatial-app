# %% [markdown]
# # Building Footprint Extraction for the USA
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/building_footprints_usa.ipynb)
#
# ## Install package
# To use the `geoai-py` package, ensure it is installed in your environment. Uncomment the command below if needed.

# %%
# %pip install geoai-py
# Out:
# Collecting geoai-py
#   Downloading geoai_py-0.8.0-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 KB 5.6 MB/s eta 0:00:00
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (54.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 MB 76.5 MB/s eta 0:00:0000:0100:01
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.33.2-py3-none-any.whl (515 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.4/515.4 KB 175.3 MB/s eta 0:00:00
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Collecting torch
#   Downloading torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl (821.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 6.7 MB/s eta 0:00:0000:0100:01
# Collecting mapclassify
#   Downloading mapclassify-2.8.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 KB 50.5 MB/s eta 0:00:00
# Collecting albumentations
#   Downloading albumentations-2.0.8-py3-none-any.whl (369 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.4/369.4 KB 86.5 MB/s eta 0:00:00
# Collecting planetary-computer
#   Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Collecting scikit-image
#   Downloading scikit_image-0.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 168.7 MB/s eta 0:00:0000:0100:01
# Collecting rioxarray
#   Downloading rioxarray-0.19.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 KB 56.0 MB/s eta 0:00:00
# Collecting maplibre
#   Downloading maplibre-0.3.4-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 117.4 MB/s eta 0:00:00
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 68.6 MB/s eta 0:00:0000:0100:01
# Collecting torchgeo
#   Downloading torchgeo-0.6.2-py3-none-any.whl (454 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.7/454.7 KB 140.6 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.53.1-py3-none-any.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 173.0 MB/s eta 0:00:00a 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 62.0 MB/s eta 0:00:00
# Collecting jupyter-server-proxy
#   Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl (37 kB)
# Collecting localtileserver
#   Downloading localtileserver-0.10.6-py3-none-any.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 140.4 MB/s eta 0:00:0000:0100:01
# Collecting pystac-client
#   Downloading pystac_client-0.8.6-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 KB 20.1 MB/s eta 0:00:00
# Collecting overturemaps
#   Downloading overturemaps-0.15.0-py3-none-any.whl (9.9 kB)
# Collecting geopandas
#   Downloading geopandas-1.1.1-py3-none-any.whl (338 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.4/338.4 KB 106.1 MB/s eta 0:00:00
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 178.0 MB/s eta 0:00:00a 0:00:01
# Collecting contextily
#   Downloading contextily-1.6.2-py3-none-any.whl (17 kB)
# Collecting leafmap
#   Downloading leafmap-0.48.6-py2.py3-none-any.whl (568 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.1/568.1 KB 182.5 MB/s eta 0:00:00
# Collecting buildingregulariser
#   Downloading buildingregulariser-0.2.2-py3-none-any.whl (19 kB)
# Collecting PyYAML
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 KB 196.6 MB/s eta 0:00:00
# Collecting numpy>=1.24.4
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 176.7 MB/s eta 0:00:00a 0:00:01
# Collecting pydantic>=2.9.2
#   Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.8/444.8 KB 170.8 MB/s eta 0:00:00
# Collecting scipy>=1.10.0
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 89.8 MB/s eta 0:00:0000:0100:01
# Collecting albucore==0.0.24
#   Downloading albucore-0.0.24-py3-none-any.whl (15 kB)
# Collecting simsimd>=5.9.2
#   Downloading simsimd-6.5.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 198.1 MB/s eta 0:00:00
# Collecting stringzilla>=3.10.4
#   Downloading stringzilla-3.12.5-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.7/304.7 KB 143.4 MB/s eta 0:00:00
# Collecting shapely>=2.0.0
#   Downloading shapely-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 227.3 MB/s eta 0:00:00
# Collecting pyogrio>=0.7.2
#   Downloading pyogrio-0.11.0-cp310-cp310-manylinux_2_28_x86_64.whl (27.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.6/27.6 MB 116.7 MB/s eta 0:00:0000:0100:01
# Collecting pyproj>=3.5.0
#   Downloading pyproj-3.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 209.2 MB/s eta 0:00:00a 0:00:01
# Collecting pandas>=2.0.0
#   Downloading pandas-2.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 231.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging in /workspace/env/lib/python3.10/site-packages (from geopandas->geoai-py) (25.0)
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 276.9 MB/s eta 0:00:00
# Collecting mercantile
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Collecting requests
#   Downloading requests-2.32.4-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 KB 39.4 MB/s eta 0:00:00
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 KB 91.2 MB/s eta 0:00:00
# Collecting xyzservices
#   Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 KB 70.6 MB/s eta 0:00:00
# Collecting pillow
#   Downloading pillow-11.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 120.0 MB/s eta 0:00:00 0:00:01
# Collecting joblib
#   Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 KB 159.8 MB/s eta 0:00:00
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 KB 21.0 MB/s eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting hf-xet<2.0.0,>=1.1.2
#   Downloading hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 124.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /workspace/env/lib/python3.10/site-packages (from huggingface_hub->geoai-py) (4.14.1)
# Requirement already satisfied: traitlets>=5.1.0 in /workspace/env/lib/python3.10/site-packages (from jupyter-server-proxy->geoai-py) (5.14.3)
# Collecting aiohttp
#   Downloading aiohttp-3.12.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 110.6 MB/s eta 0:00:00
# Requirement already satisfied: tornado>=6.1.0 in /workspace/env/lib/python3.10/site-packages (from jupyter-server-proxy->geoai-py) (6.5.1)
# Collecting jupyter-server>=1.24.0
#   Downloading jupyter_server-2.16.0-py3-none-any.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 KB 155.3 MB/s eta 0:00:00
# Collecting simpervisor>=1.0.0
#   Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Collecting python-box
#   Downloading python_box-7.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 210.3 MB/s eta 0:00:00
# Collecting plotly
#   Downloading plotly-6.2.0-py3-none-any.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 261.7 MB/s eta 0:00:0000:01
# Collecting ipyfilechooser
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 KB 102.4 MB/s eta 0:00:00
# Collecting ipyvuetify
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 176.2 MB/s eta 0:00:0000:01
# Collecting scooby
#   Downloading scooby-0.10.1-py3-none-any.whl (18 kB)
# Collecting bqplot
#   Downloading bqplot-0.12.45-py2.py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 134.1 MB/s eta 0:00:00
# Collecting whiteboxgui
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 KB 50.7 MB/s eta 0:00:00
# Collecting anywidget
#   Downloading anywidget-0.9.18-py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 KB 69.5 MB/s eta 0:00:00
# Collecting duckdb
#   Downloading duckdb-1.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 202.9 MB/s eta 0:00:0000:0100:01
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Collecting geojson
#   Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Collecting ipyleaflet
#   Downloading ipyleaflet-0.20.0-py3-none-any.whl (31 kB)
# Collecting ipyevents
#   Downloading ipyevents-2.0.2-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 KB 68.2 MB/s eta 0:00:00
# Collecting folium
#   Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.4/113.4 KB 50.6 MB/s eta 0:00:00
# Collecting rio-tiler
#   Downloading rio_tiler-7.8.1-py3-none-any.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 KB 160.1 MB/s eta 0:00:00
# Collecting flask-cors
#   Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Collecting flask-restx>=1.3.0
#   Downloading flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 271.3 MB/s eta 0:00:00
# Collecting click
#   Downloading click-8.2.1-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 KB 88.0 MB/s eta 0:00:00
# Collecting flask<4,>=2.0.0
#   Downloading flask-3.1.1-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 KB 90.0 MB/s eta 0:00:00
# Collecting werkzeug
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 KB 133.4 MB/s eta 0:00:00
# Collecting server-thread
#   Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Collecting rio-cogeo
#   Downloading rio_cogeo-5.4.2-py3-none-any.whl (21 kB)
# Collecting Flask-Caching
#   Downloading Flask_Caching-2.3.1-py3-none-any.whl (28 kB)
# Collecting networkx>=2.7
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 215.7 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting eval-type-backport
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Collecting branca
#   Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Collecting jinja2>=3.1.6
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 KB 108.7 MB/s eta 0:00:00
# Collecting pyarrow>=15.0.2
#   Downloading pyarrow-20.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (42.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 98.7 MB/s eta 0:00:0000:0100:01
# Collecting pystac>=1.0.0
#   Downloading pystac-1.13.0-py3-none-any.whl (206 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.8/206.8 KB 129.5 MB/s eta 0:00:00
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Collecting pytz>=2020.5
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 KB 186.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspace/env/lib/python3.10/site-packages (from pystac-client->geoai-py) (2.9.0.post0)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting certifi
#   Downloading certifi-2025.6.15-py3-none-any.whl (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.7/157.7 KB 122.5 MB/s eta 0:00:00
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Collecting pyparsing
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 KB 74.1 MB/s eta 0:00:00
# Collecting attrs
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 KB 62.3 MB/s eta 0:00:00
# Collecting xarray>=2024.7.0
#   Downloading xarray-2025.6.1-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 235.5 MB/s eta 0:00:00
# Collecting lazy-loader>=0.4
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2025.5.10-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.5/226.5 KB 139.1 MB/s eta 0:00:00
# Collecting imageio!=2.35.0,>=2.33
#   Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.8/315.8 KB 159.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.6.80
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 98.9 MB/s eta 0:00:00ta 0:00:01
# Collecting nvidia-cublas-cu12==12.6.4.1
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 14.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12==12.5.4.2
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 22.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufile-cu12==1.11.1.6
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 243.9 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.26.2
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 26.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu12==12.6.77
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 KB 239.1 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.6.77
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 KB 73.6 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12==12.6.85
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 204.4 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cusolver-cu12==11.7.1.2
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 29.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparselt-cu12==0.6.3
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 24.0 MB/s eta 0:00:0000:0100:01
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 213.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 199.3 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cudnn-cu12==9.5.1.17
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 10.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu12==11.3.0.4
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 27.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.7.77
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 73.1 MB/s eta 0:00:0000:0100:01
# Collecting triton==3.3.1
#   Downloading triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 36.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools>=40.8.0 in /workspace/env/lib/python3.10/site-packages (from triton==3.3.1->torch->geoai-py) (59.6.0)
# Collecting einops>=0.3
#   Downloading einops-0.8.1-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 KB 56.6 MB/s eta 0:00:00
# Collecting torchvision>=0.14
#   Downloading torchvision-0.22.1-cp310-cp310-manylinux_2_28_x86_64.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 125.8 MB/s eta 0:00:00 0:00:01
# Collecting segmentation-models-pytorch>=0.2
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 KB 117.8 MB/s eta 0:00:00
# Collecting lightly!=1.4.26,>=1.4.5
#   Downloading lightly-1.5.21-py3-none-any.whl (855 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 855.8/855.8 KB 152.8 MB/s eta 0:00:00
# Collecting torchmetrics>=0.10
#   Downloading torchmetrics-1.7.4-py3-none-any.whl (963 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 KB 215.9 MB/s eta 0:00:00
# Collecting rtree>=1
#   Downloading rtree-1.4.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (541 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.1/541.1 KB 162.3 MB/s eta 0:00:00
# Collecting lightning[pytorch-extra]!=2.3.*,>=2
#   Downloading lightning-2.5.2-py3-none-any.whl (821 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.1/821.1 KB 182.3 MB/s eta 0:00:00
# Collecting kornia>=0.7.3
#   Downloading kornia-0.8.1-py2.py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 252.2 MB/s eta 0:00:00
# Collecting fiona>=1.8.21
#   Downloading fiona-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 159.3 MB/s eta 0:00:0000:0100:01
# Collecting timm>=0.4.12
#   Downloading timm-1.0.16-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 158.0 MB/s eta 0:00:00
# Collecting regex!=2019.12.17
#   Downloading regex-2024.11.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.7/781.7 KB 201.1 MB/s eta 0:00:00
# Collecting tokenizers<0.22,>=0.21
#   Downloading tokenizers-0.21.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 131.3 MB/s eta 0:00:00
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 KB 167.9 MB/s eta 0:00:00
# Collecting markupsafe>=2.1.1
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Collecting itsdangerous>=2.2.0
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting blinker>=1.9.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting aniso8601>=0.82
#   Downloading aniso8601-10.0.1-py2.py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 KB 47.5 MB/s eta 0:00:00
# Collecting importlib-resources
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting jsonschema
#   Downloading jsonschema-4.24.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 KB 80.2 MB/s eta 0:00:00
# Collecting jupyter-events>=0.11.0
#   Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Collecting overrides>=5.0
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting websocket-client>=1.7
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 46.6 MB/s eta 0:00:00
# Requirement already satisfied: pyzmq>=24 in /workspace/env/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (27.0.0)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Collecting send2trash>=1.8.2
#   Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Collecting argon2-cffi>=21.1
#   Downloading argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: jupyter-client>=7.4.4 in /workspace/env/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (8.6.3)
# Collecting anyio>=3.1.0
#   Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 KB 85.6 MB/s eta 0:00:00
# Collecting prometheus-client>=0.9
#   Downloading prometheus_client-0.22.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 KB 53.2 MB/s eta 0:00:00
# Collecting nbconvert>=6.4.4
#   Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 KB 148.7 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /workspace/env/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (5.8.1)
# Collecting jupyter-server-terminals>=0.4.4
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Collecting nbformat>=5.3.0
#   Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 41.1 MB/s eta 0:00:00
# Collecting kornia_rs>=0.1.9
#   Downloading kornia_rs-0.1.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 278.0 MB/s eta 0:00:00
# Collecting hydra-core>=1.0.0
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 KB 105.7 MB/s eta 0:00:00
# Collecting lightly_utils~=0.0.0
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Collecting urllib3>=1.25.3
#   Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 KB 104.2 MB/s eta 0:00:00
# Collecting aenum>=3.1.11
#   Downloading aenum-3.1.16-py3-none-any.whl (165 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 KB 118.0 MB/s eta 0:00:00
# Collecting pytorch_lightning>=1.0.4
#   Downloading pytorch_lightning-2.5.2-py3-none-any.whl (825 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.4/825.4 KB 223.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.10 in /workspace/env/lib/python3.10/site-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (1.17.0)
# Collecting lightning-utilities<2.0,>=0.10.0
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Collecting rich<15.0,>=12.3.0
#   Downloading rich-14.0.0-py3-none-any.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 KB 152.1 MB/s eta 0:00:00
# Collecting bitsandbytes<1.0,>=0.45.2
#   Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl (72.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 67.3 MB/s eta 0:00:0000:0100:01
# Collecting jsonargparse[jsonnet,signatures]<5.0,>=4.39.0
#   Downloading jsonargparse-4.40.0-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.3/224.3 KB 153.5 MB/s eta 0:00:00
# Collecting omegaconf<3.0,>=2.2.3
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 64.5 MB/s eta 0:00:00
# Collecting tensorboardX<3.0,>=2.2
#   Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 KB 77.2 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 KB 168.4 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.58.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 259.9 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 242.2 MB/s eta 0:00:00
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 KB 187.1 MB/s eta 0:00:00
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 176.0 MB/s eta 0:00:00
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.5/149.5 KB 109.0 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 KB 67.9 MB/s eta 0:00:00
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 178.6 MB/s eta 0:00:00
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.7.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.9/222.9 KB 134.7 MB/s eta 0:00:00
# Collecting propcache>=0.2.0
#   Downloading propcache-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.3/198.3 KB 130.5 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.6.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.6/241.6 KB 137.6 MB/s eta 0:00:00
# Collecting aiohappyeyeballs>=2.5.0
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.1/326.1 KB 34.7 MB/s eta 0:00:00
# Collecting psygnal>=0.8.1
#   Downloading psygnal-0.14.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (847 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.0/848.0 KB 197.6 MB/s eta 0:00:00
# Requirement already satisfied: comm>=0.1.3 in /workspace/env/lib/python3.10/site-packages (from ipywidgets->leafmap->geoai-py) (0.2.2)
# Collecting widgetsnbextension~=4.0.14
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 261.8 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=6.1.0 in /workspace/env/lib/python3.10/site-packages (from ipywidgets->leafmap->geoai-py) (8.37.0)
# Collecting jupyterlab_widgets~=3.0.15
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 KB 132.6 MB/s eta 0:00:00
# Collecting traittypes>=0.0.6
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Collecting cachelib>=0.9.0
#   Downloading cachelib-0.13.0-py3-none-any.whl (20 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.3/187.3 KB 136.2 MB/s eta 0:00:00
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 KB 35.4 MB/s eta 0:00:00
# Collecting jupyter-leaflet<0.21,>=0.20
#   Downloading jupyter_leaflet-0.20.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 142.5 MB/s eta 0:00:00
# Collecting ipyvue<2,>=1.7
#   Downloading ipyvue-1.11.2-py2.py3-none-any.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 159.0 MB/s eta 0:00:00
# Collecting narwhals>=1.15.1
#   Downloading narwhals-1.46.0-py3-none-any.whl (373 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.4/373.4 KB 175.5 MB/s eta 0:00:00
# Collecting morecantile<7.0,>=5.0
#   Downloading morecantile-6.2.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 KB 43.5 MB/s eta 0:00:00
# Collecting color-operations
#   Downloading color_operations-0.2.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (186 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.5/186.5 KB 132.2 MB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 61.6 MB/s eta 0:00:00
# Collecting numexpr
#   Downloading numexpr-2.11.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (399 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.8/399.8 KB 173.5 MB/s eta 0:00:00
# Collecting cachetools
#   Downloading cachetools-6.1.0-py3-none-any.whl (11 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 KB 56.2 MB/s eta 0:00:00
# Collecting whitebox
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 KB 65.2 MB/s eta 0:00:00
# Collecting ipytree
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 122.5 MB/s eta 0:00:00
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /workspace/env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (1.3.0)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 KB 76.4 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.*
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Requirement already satisfied: stack_data in /workspace/env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (0.6.3)
# Requirement already satisfied: matplotlib-inline in /workspace/env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (0.1.7)
# Requirement already satisfied: pygments>=2.4.0 in /workspace/env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (2.19.2)
# Requirement already satisfied: decorator in /workspace/env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (5.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /workspace/env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (3.0.51)
# Requirement already satisfied: jedi>=0.16 in /workspace/env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /workspace/env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (4.9.0)
# Collecting typeshed-client>=2.3.0
#   Downloading typeshed_client-2.7.0-py3-none-any.whl (624 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 KB 207.5 MB/s eta 0:00:00
# Collecting docstring-parser>=0.15
#   Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Collecting jsonnet>=0.21.0
#   Downloading jsonnet-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 166.3 MB/s eta 0:00:00a 0:00:01
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (383 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.8/383.8 KB 157.6 MB/s eta 0:00:00
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.4.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: platformdirs>=2.5 in /workspace/env/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (4.3.8)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 KB 43.7 MB/s eta 0:00:00
# Collecting bleach[css]!=5.0.0
#   Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 KB 128.4 MB/s eta 0:00:00
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Collecting fastjsonschema>=2.15
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 KB 74.4 MB/s eta 0:00:00
# Collecting protobuf>=3.20
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.1/321.1 KB 160.6 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess in /workspace/env/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (0.7.0)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 KB 68.0 MB/s eta 0:00:00
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /workspace/env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (0.8.4)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting webcolors>=24.6.0
#   Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: wcwidth in /workspace/env/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (0.2.13)
# Collecting cffi>=1.0.1
#   Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 KB 167.1 MB/s eta 0:00:00
# Requirement already satisfied: asttokens>=2.1.0 in /workspace/env/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /workspace/env/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (2.2.0)
# Requirement already satisfied: pure-eval in /workspace/env/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (0.2.3)
# Collecting pycparser
#   Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 KB 98.3 MB/s eta 0:00:00
# Collecting arrow>=0.15.0
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 KB 62.1 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10
#   Downloading types_python_dateutil-2.9.0.20250708-py3-none-any.whl (17 kB)
# Installing collected packages: webencodings, stringzilla, simsimd, pytz, nvidia-cusparselt-cu12, mpmath, jsonnet, fastjsonschema, antlr4-python3-runtime, aniso8601, aenum, xyzservices, widgetsnbextension, websocket-client, webcolors, urllib3, uri-template, tzdata, typing-inspection, types-python-dateutil, triton, traittypes, tqdm, torchinfo, tinycss2, threadpoolctl, terminado, sympy, soupsieve, sniffio, simpervisor, send2trash, scooby, safetensors, rtree, rpds-py, rfc3986-validator, rfc3339-validator, regex, PyYAML, python-json-logger, python-dotenv, python-box, PySocks, pyparsing, pydantic-core, pycparser, pyarrow, psygnal, protobuf, propcache, prometheus-client, pillow, pandocfilters, overrides, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, narwhals, multidict, mistune, mdurl, markupsafe, lightning-utilities, lazy-loader, kornia_rs, kiwisolver, jupyterlab_widgets, jupyterlab-pygments, jupyter-leaflet, jsonpointer, joblib, itsdangerous, importlib-resources, idna, hf-xet, h11, geojson, geographiclib, fsspec, frozenlist, fqdn, fonttools, filelock, eval-type-backport, einops, duckdb, docstring-parser, defusedxml, cycler, click, charset_normalizer, certifi, cachetools, cachelib, blinker, bleach, attrs, async-timeout, annotated-types, aiohappyeyeballs, affine, yarl, whitebox, werkzeug, uvicorn, typeshed-client, tifffile, tensorboardX, shapely, scipy, requests, referencing, pystac, pyproj, pyogrio, pydantic, plotly, pandas, opencv-python-headless, omegaconf, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, numexpr, mercantile, markdown-it-py, lightly_utils, jupyter-server-terminals, jsonargparse, jinja2, imageio, httpcore, geopy, contourpy, color-operations, cligj, click-plugins, cffi, beautifulsoup4, arrow, anyio, aiosignal, xarray, server-thread, scikit-learn, scikit-image, rich, rasterio, overturemaps, nvidia-cusolver-cu12, morecantile, matplotlib, jsonschema-specifications, isoduration, ipywidgets, hydra-core, huggingface_hub, httpx, geopandas, flask, fiona, branca, argon2-cffi-bindings, albucore, aiohttp, torch, tokenizers, rioxarray, rio-tiler, rio-cogeo, maplibre, mapclassify, jsonschema, ipyvue, ipytree, ipyleaflet, ipyfilechooser, ipyevents, gdown, folium, flask-cors, Flask-Caching, contextily, buildingregulariser, bqplot, argon2-cffi, anywidget, albumentations, whiteboxgui, transformers, torchvision, torchmetrics, nbformat, kornia, ipyvuetify, flask-restx, bitsandbytes, timm, pytorch_lightning, pystac-client, nbclient, localtileserver, jupyter-events, segmentation-models-pytorch, planetary-computer, nbconvert, lightning, lightly, leafmap, jupyter-server, torchgeo, jupyter-server-proxy, geoai-py

# %% [markdown]
# ## Import libraries

# %%
import geoai
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import geoai
#
# ModuleNotFoundError: No module named 'geoai'

# %% [markdown]
# ## Download sample data

# %%
raster_url = (
    "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/naip_train.tif"
)
vector_url = "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/naip_train_buildings.geojson"

# %%
raster_path = geoai.download_file(raster_url)

# %%
vector_path = geoai.download_file(vector_url)

# %% [markdown]
# ## Initialize building footprint extraction pretrained model

# %%
extractor = geoai.BuildingFootprintExtractor()

# %% [markdown]
# ## Extract building footprints
#
# ### Option 1: Extract building footprints as raster

# %%
mask_path = extractor.save_masks_as_geotiff(
    raster_path=raster_path,
    output_path="building_masks.tif",
    confidence_threshold=0.5,
    mask_threshold=0.5,
)

# %% [markdown]
# Convert raster to vector

# %%
gdf = extractor.masks_to_vector(
    mask_path=mask_path,
    output_path="building_masks.geojson",
    simplify_tolerance=1.0,
)

# %% [markdown]
# ### Option 2: Extract building footprints as vector

# %%
output_path = "naip_buildings.geojson"
gdf = extractor.process_raster(
    raster_path,
    output_path="buildings.geojson",
    batch_size=4,
    confidence_threshold=0.5,
    overlap=0.25,
    nms_iou_threshold=0.5,
    min_object_area=100,
    max_object_area=None,
    mask_threshold=0.5,
    simplify_tolerance=1.0,
)

# %% [markdown]
# ## Regularize building footprints

# %%
gdf_regularized = extractor.regularize_buildings(
    gdf=gdf,
    min_area=100,
    angle_threshold=15,
    orthogonality_threshold=0.3,
    rectangularity_threshold=0.7,
)

# %% [markdown]
# ## Visualize building footprints

# %%
gdf.head()

# %%
geoai.view_vector_interactive(
    gdf, column="confidence", layer_name="Building", tiles="Satellite"
)

# %%
geoai.view_vector_interactive(
    gdf, column="confidence", layer_name="Building", tiles=raster_url
)

# %%
geoai.view_vector_interactive(
    gdf_regularized, column="confidence", layer_name="Building", tiles=raster_url
)

# %%
extractor.visualize_results(raster_path, gdf, output_path="naip_buildings.png")

# %%
extractor.visualize_results(
    raster_path, gdf_regularized, output_path="naip_buildings_regularized.png"
)
