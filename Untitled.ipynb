# %%
#%pip install segment-geospatial
#%pip install GDAL
# Out:
# Collecting GDAL
#   Downloading gdal-3.11.1.tar.gz (878 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 878.1/878.1 KB 13.2 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [90 lines of output]
#       Using numpy 2.2.6
#       /tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/config/_apply_pyprojecttoml.py:82: SetuptoolsWarning: `license` overwritten by `pyproject.toml`
#         corresp(dist, value, root_dir)
#       /tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/config/_apply_pyprojecttoml.py:82: SetuptoolsWarning: `extras_require` overwritten in `pyproject.toml` (optional-dependencies)
#         corresp(dist, value, root_dir)
#       running egg_info
#       writing gdal-utils/GDAL.egg-info/PKG-INFO
#       writing dependency_links to gdal-utils/GDAL.egg-info/dependency_links.txt
#       writing entry points to gdal-utils/GDAL.egg-info/entry_points.txt
#       writing requirements to gdal-utils/GDAL.egg-info/requires.txt
#       writing top-level names to gdal-utils/GDAL.egg-info/top_level.txt
#       Traceback (most recent call last):
#         File "<string>", line 92, in fetch_config
#         File "/usr/lib/python3.10/subprocess.py", line 971, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#         File "/usr/lib/python3.10/subprocess.py", line 1863, in _execute_child
#           raise child_exception_type(errno_num, err_msg, err_filename)
#       FileNotFoundError: [Errno 2] No such file or directory: 'gdal-config'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 244, in get_gdal_config
#         File "<string>", line 95, in fetch_config
#       __main__.gdal_config_error: [Errno 2] No such file or directory: 'gdal-config'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "/workspace/env/lib/python3.10/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 363, in <module>
#           main()
#         File "/workspace/env/lib/python3.10/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 345, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/workspace/env/lib/python3.10/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 130, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 331, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 456, in <module>
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/__init__.py", line 115, in setup
#           return distutils.core.setup(**attrs)
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 186, in setup
#           return run_commands(dist)
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 202, in run_commands
#           dist.run_commands()
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 1002, in run_commands
#           self.run_command(cmd)
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/dist.py", line 1102, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 1021, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 312, in run
#           self.find_sources()
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 320, in find_sources
#           mm.run()
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 543, in run
#           self.add_defaults()
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 581, in add_defaults
#           sdist.add_defaults(self)
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/command/sdist.py", line 109, in add_defaults
#           super().add_defaults()
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/_distutils/command/sdist.py", line 245, in add_defaults
#           self._add_defaults_ext()
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/_distutils/command/sdist.py", line 329, in _add_defaults_ext
#           build_ext = self.get_finalized_command('build_ext')
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 334, in get_finalized_command
#           cmd_obj.ensure_finalized()
#         File "/tmp/pip-build-env-6e9bhf_k/overlay/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 135, in ensure_finalized
#           self.finalize_options()
#         File "<string>", line 328, in finalize_options
#         File "<string>", line 250, in get_gdal_config
#       __main__.gdal_config_error: Traceback (most recent call last):
#         File "<string>", line 92, in fetch_config
#         File "/usr/lib/python3.10/subprocess.py", line 971, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#         File "/usr/lib/python3.10/subprocess.py", line 1863, in _execute_child
#           raise child_exception_type(errno_num, err_msg, err_filename)
#       FileNotFoundError: [Errno 2] No such file or directory: 'gdal-config'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 244, in get_gdal_config
#         File "<string>", line 95, in fetch_config
#       gdal_config_error: [Errno 2] No such file or directory: 'gdal-config'
#
#       Could not find gdal-config. Make sure you have installed the GDAL native library and development headers.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import leafmap
from samgeo import SamGeo, tms_to_geotiff, get_basemaps

# %%
m = leafmap.Map(center=[37.3269, -121.95], zoom=19)
m.add_basemap("SATELLITE")
m
# Out:
# Map(center=[37.3269, -121.95], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
if m.user_roi_bounds() is not None:
    bbox = m.user_roi_bounds()
else:
    bbox = [-95.3704, 29.6762, -95.368, 29.6775]

# %%
bbox
# Out:
# [-121.9504, 37.3235, -121.9405, 37.3271]

# %%
get_basemaps().keys()
# Out:
# dict_keys(['BaseMapDE.Color', 'BaseMapDE.Grey', 'BasemapAT.basemap', 'BasemapAT.grau', 'BasemapAT.highdpi', 'BasemapAT.orthofoto', 'BasemapAT.overlay', 'BasemapAT.surface', 'BasemapAT.terrain', 'CartoDB.DarkMatter', 'CartoDB.DarkMatterNoLabels', 'CartoDB.DarkMatterOnlyLabels', 'CartoDB.Positron', 'CartoDB.PositronNoLabels', 'CartoDB.PositronOnlyLabels', 'CartoDB.Voyager', 'CartoDB.VoyagerLabelsUnder', 'CartoDB.VoyagerNoLabels', 'CartoDB.VoyagerOnlyLabels', 'CyclOSM', 'Esri.AntarcticBasemap', 'Esri.AntarcticImagery', 'Esri.ArcticImagery', 'Esri.ArcticOceanBase', 'Esri.ArcticOceanReference', 'Esri.NatGeoWorldMap', 'Esri.OceanBasemap', 'Esri.WorldGrayCanvas', 'Esri.WorldImagery', 'Esri.WorldPhysical', 'Esri.WorldShadedRelief', 'Esri.WorldStreetMap', 'Esri.WorldTerrain', 'Esri.WorldTopoMap', 'FreeMapSK', 'Gaode.Normal', 'Gaode.Satellite', 'GeoportailFrance.500k', 'GeoportailFrance.Acces_Biomethane', 'GeoportailFrance.Adminexpress_cog_2017', 'GeoportailFrance.Adminexpress_cog_2
# Downloaded image 374/420
# Downloaded image 375/420
# Downloaded image 376/420
# Downloaded image 377/420
# Downloaded image 378/420
# Downloaded image 379/420
# Downloaded image 380/420
# Downloaded image 381/420
# Downloaded image 382/420
# Downloaded image 383/420
# Downloaded image 384/420
# Downloaded image 385/420
# Downloaded image 386/420
# Downloaded image 387/420
# Downloaded image 388/420
# Downloaded image 389/420
# Downloaded image 390/420
# Downloaded image 391/420
# Downloaded image 392/420
# Downloaded image 393/420
# Downloaded image 394/420
# Downloaded image 395/420
# Downloaded image 396/420
# Downloaded image 397/420
# Downloaded image 398/420
# Downloaded image 399/420
# Downloaded image 400/420
# Downloaded image 401/420
# Downloaded image 402/420
# Downloaded image 403/420
# Downloaded image 404/420
# Downloaded image 405/420
# Downloaded image 406/420
# Downloaded image 407/420
# Downloaded image 408/420
# Downloaded image 409/420
# Downloaded image 410/420
# Downloaded image 411/420
# Downloaded image 412/420
# Downloaded image 413/420
# Downloaded image 414/420
# Downloaded image 415/420
# Downloaded image 416/420
# Downloaded image 417/420
# Downloaded image 418/420
# Downloaded image 419/420
# Downloaded image 420/420
# Saving GeoTIFF. Please wait...
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/workspace/env/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/workspace/env/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/workspace/env/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/workspace/env/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/workspace/env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/workspace/env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/workspace/env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/workspace/env/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/workspace/env/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/workspace/env/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/workspace/env/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/workspace/env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "/workspace/env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "/workspace/env/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/workspace/env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/workspace/env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/workspace/env/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_7001/974596320.py", line 2, in <module>
#     tms_to_geotiff(output=image, bbox=bbox, zoom=20, source="Satellite", overwrite=True)
#   File "/workspace/env/lib/python3.10/site-packages/samgeo/common.py", line 659, in tms_to_geotiff
#     image = draw_tile(
#   File "/workspace/env/lib/python3.10/site-packages/samgeo/common.py", line 651, in draw_tile
#     band.WriteArray(array)
#   File "/workspace/env/lib/python3.10/site-packages/osgeo/gdal.py", line 4088, in WriteArray
#     return _gdal.Group_OpenGroup(self, *args)
#   File "/workspace/env/lib/python3.10/site-packages/osgeo/gdal_array.py", line 10, in <module>
#     from . import _gdal_array
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /workspace/env/lib/python3.10/site-packages/samgeo/common.py:659, in tms_to_geotiff(output, bbox, zoom, resolution, source, crs, to_cog, return_image, overwrite, quiet, **kwargs)
#     658 try:
# --> 659     image = draw_tile(
#     660         source, south, west, north, east, zoom, output, quiet, **kwargs
#     661     )
#     662     if return_image:
#
# File /workspace/env/lib/python3.10/site-packages/samgeo/common.py:651, in tms_to_geotiff.<locals>.draw_tile(source, lat0, lon0, lat1, lon1, zoom, filename, quiet, **kwargs)
#     650     band = gtiff.GetRasterBand(band + 1)
# --> 651     band.WriteArray(array)
#     652 gtiff.FlushCache()
#
# File /workspace/env/lib/python3.10/site-packages/osgeo/gdal.py:4088, in Band.WriteArray(self, array, xoff, yoff, resample_alg, callback, callback_data)
#    4084 def WriteArray(self, array, xoff=0, yoff=0,
#    4085                resample_alg=gdalconst.GRIORA_NearestNeighbour,
#    4086                callback=None,
#    4087                callback_data=None):
# -> 4088     from osgeo import gdal_array
#    4090     return gdal_array.BandWriteArray(self, array, xoff, yoff,
#    4091                                       resample_alg=resample_alg,
#    4092                                       callback=callback,
#    4093                                       callback_data=callback_data)
#
# File /workspace/env/lib/python3.10/site-packages/osgeo/gdal_array.py:10
#       9 if __package__ or "." in __name__:
# ---> 10     from . import _gdal_array
#      11 else:
#
# ImportError: numpy.core.multiarray failed to import
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 image = "satellite.tif"
# ----> 2 tms_to_geotiff(output=image, bbox=bbox, zoom=20, source="Satellite", overwrite=True)
#
# File /workspace/env/lib/python3.10/site-packages/samgeo/common.py:669, in tms_to_geotiff(output, bbox, zoom, resolution, source, crs, to_cog, return_image, overwrite, quiet, **kwargs)
#     667         image_to_cog(output, output)
#     668 except Exception as e:
# --> 669     raise Exception(e)
#
# Exception: numpy.core.multiarray failed to import

# %%
m.layers[-1].visible = False  # turn off the basemap
m.add_raster(image, layer_name="Image")
m
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio/_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/workspace/geospatial-app/satellite.tif' not recognized as being in a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[13], line 2
#       1 m.layers[-1].visible = False  # turn off the basemap
# ----> 2 m.add_raster(image, layer_name="Image")
#       3 m
#
# File /workspace/env/lib/python3.10/site-packages/leafmap/leafmap.py:2474, in Map.add_raster(self, source, indexes, colormap, vmin, vmax, nodata, attribution, layer_name, layer_index, zoom_to_layer, visible, opacity, array_args, client_args, overwrite, **kwargs)
#    2471 if isinstance(source, np.ndarray) or isinstance(source, xr.DataArray):
#    2472     source = common.array_to_image(source, **array_args)
# -> 2474 tile_layer = common.get_local_tile_layer(
#    2475     source,
#    2476     indexes=indexes,
#    2477     colormap=colormap,
#    2478     vmin=vmin,
#    2479     vmax=vmax,
#    2480     nodata=nodata,
#    2481     opacity=opacity,
#    2482     attribution=attribution,
#    2483     layer_name=layer_name,
#    2484     client_args=client_args,
#    2485     return_client=False,
#    2486     **kwargs,
#    2487 )
#    2488 tile_layer.visible = visible
#    2489 tile_client = tile_layer.tile_server
#
# File /workspace/env/lib/python3.10/site-packages/leafmap/common.py:3017, in get_local_tile_layer(source, port, debug, indexes, colormap, vmin, vmax, nodata, attribution, tile_format, layer_name, client_args, return_client, quiet, **kwargs)
#    3015 else:
#    3016     if tile_format == "ipyleaflet":
# -> 3017         tile_layer = get_leaflet_tile_layer(
#    3018             source,
#    3019             port=port,
#    3020             debug=debug,
#    3021             indexes=indexes,
#    3022             colormap=colormap,
#    3023             vmin=vmin,
#    3024             vmax=vmax,
#    3025             nodata=nodata,
#    3026             attribution=attribution,
#    3027             name=layer_name,
#    3028             **kwargs,
#    3029         )
#    3030     else:
#    3031         tile_layer = get_folium_tile_layer(
#    3032             source,
#    3033             port=port,
#    (...)
#    3043             **kwargs,
#    3044         )
#
# File /workspace/env/lib/python3.10/site-packages/localtileserver/widgets.py:100, in get_leaflet_tile_layer(source, port, debug, indexes, colormap, vmin, vmax, nodata, attribution, **kwargs)
#      95 class BoundTileLayer(TileLayer, LocalTileServerLayerMixin):
#      96     # https://github.com/jupyter-widgets/ipyleaflet/issues/888
#      97     # https://github.com/ipython/traitlets/issues/626#issuecomment-699957829
#      98     bounds = Union((Tuple(),), default_value=None, allow_none=True).tag(sync=True, o=True)
# --> 100 source, created = get_or_create_tile_client(
#     101     source,
#     102     port=port,
#     103     debug=debug,
#     104 )
#     105 url = source.get_tile_url(
#     106     indexes=indexes,
#     107     colormap=colormap,
#    (...)
#     111     client=True,
#     112 )
#     113 if attribution is None:
#
# File /workspace/env/lib/python3.10/site-packages/localtileserver/client.py:596, in get_or_create_tile_client(source, port, debug)
#     594 # Launch tile server if file path is given
#     595 if not isinstance(source, TileClient):
# --> 596     source = TileClient(source, port=port, debug=debug)
#     597     _internally_created = True
#     599 # Check that the tile source is valid and no server errors
#
# File /workspace/env/lib/python3.10/site-packages/localtileserver/client.py:561, in TileClient.__init__(self, source, port, debug, host, client_port, client_host, client_prefix, cors_all)
#     550 def __init__(
#     551     self,
#     552     source: Union[pathlib.Path, str, rasterio.io.DatasetReaderBase],
#    (...)
#     559     cors_all: bool = False,
#     560 ):
# --> 561     TilerInterface.__init__(self, source=source)
#     562     TileServerMixin.__init__(
#     563         self,
#     564         port=port,
#    (...)
#     570         cors_all=cors_all,
#     571     )
#
# File /workspace/env/lib/python3.10/site-packages/localtileserver/client.py:64, in TilerInterface.__init__(self, source)
#      62     self._reader = source
#      63 else:
# ---> 64     self._reader = get_reader(source)
#
# File /workspace/env/lib/python3.10/site-packages/localtileserver/tiler/handler.py:24, in get_reader(path)
#      23 def get_reader(path: Union[pathlib.Path, str]) -> Reader:
# ---> 24     return Reader(get_clean_filename(path))
#
# File <attrs generated methods rio_tiler.io.rasterio.Reader>:45, in __init__(self, input, dataset, tms, colormap, options)
#      43     self.options = __attr_factory_options(self)
#      44 self._ctx_stack = __attr_factory__ctx_stack()
# ---> 45 self.__attrs_post_init__()
#
# File /workspace/env/lib/python3.10/site-packages/rio_tiler/io/rasterio.py:97, in Reader.__attrs_post_init__(self)
#      95 """Define _kwargs, open dataset and get info."""
#      96 if not self.dataset:
# ---> 97     self.dataset = self._ctx_stack.enter_context(rasterio.open(self.input))
#      99 if self.dataset.gcps[0]:
#     100     vrt_options = {
#     101         "src_crs": self.dataset.gcps[1],
#     102         "src_transform": transform.from_gcps(self.dataset.gcps[0]),
#     103         "add_alpha": True,
#     104     }
#
# File /workspace/env/lib/python3.10/site-packages/rasterio/env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File /workspace/env/lib/python3.10/site-packages/rasterio/__init__.py:356, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     353     path = _parse_path(raw_dataset_path)
#     355 if mode == "r":
# --> 356     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     357 elif mode == "r+":
#     358     dataset = get_writer_for_path(path, driver=driver)(
#     359         path, mode, driver=driver, sharing=sharing, **kwargs
#     360     )
#
# File rasterio/_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: '/workspace/geospatial-app/satellite.tif' not recognized as being in a supported file format.
